(Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143228 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143230 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143233 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143240 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143243 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143245 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143250 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143255 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143259 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143303 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143311 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143317 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143320 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143324 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143329 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143334 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_143337 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144451 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144454 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144458 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144843 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144846 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144903 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144907 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144912 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144917 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144921 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_144925 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145113 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145117 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145121 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145125 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145129 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145134 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145139 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145144 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145152 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145215 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145218 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145222 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145233 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145236 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145242 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145246 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145253 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145257 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145302 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145305 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145311 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145316 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145319 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145324 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145327 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145336 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145339 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145345 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145351 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145356 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145359 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145402 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145406 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145408 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_145957 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150000 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150308 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150310 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150314 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150321 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150324 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150331 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150335 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150341 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150345 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150350 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150352 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150355 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150358 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150401 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150405 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150408 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150412 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150421 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150513 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150516 (Custom).jpg
#   inflating: mango_leaf/New folder/Sooty Mould/IMG_20211212_150519 (Custom).jpg

# %% [markdown]
# # import library

# %%
import os
import shutil
import random

import numpy as np
from skimage import io
from PIL import Image
from keras.preprocessing import image

import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from skimage import io
import numpy as np
import os
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# Import Data Science Libraries
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import itertools
import random

# Import visualization libraries
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2

# Tensorflow Libraries
from tensorflow import keras
from tensorflow.keras import layers,models
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model

# System libraries
from pathlib import Path
import os.path
import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import skimage
from skimage.transform import resize
# label binarizer
from sklearn.preprocessing import LabelBinarizer
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# Metrics
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Mobile Net

# %% [markdown]
# ## Split data into main and test validation

# %%
from ast import main
# Define your dataset directories and the directories where you want to create the splits:

dataset_dir = "/content/mango_leaf/New folder"  # Replace with the path to your dataset
main_dir = "train_set"
test_dir = "test_set"

# Create the train, test, and validation directories if they don't exist
os.makedirs(main_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# %%
# Set the split ratio (for main 80% , for test 20%)

main_ratio = 0.80
test_ratio = 0.20

# %%
# iterate throught the folders containing our two type of data and splite them into main and test

for class_folder in os.listdir(dataset_dir):
    class_path = os.path.join(dataset_dir, class_folder)

    if os.path.isdir(class_path):
        file_list = os.listdir(class_path)
        random.shuffle(file_list)

        main_split = int(len(file_list) * main_ratio)
        test_split = int(len(file_list) * (main_ratio + test_ratio))

        main_files = file_list[:main_split]
        test_files = file_list[main_split:test_split]


        for file_name in main_files:
            src = os.path.join(class_path, file_name)
            dst = os.path.join(main_dir, class_folder, file_name)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy(src, dst)

        for file_name in test_files:
            src = os.path.join(class_path, file_name)
            dst = os.path.join(test_dir, class_folder, file_name)
            os.makedirs(os.path.dirname(dst), exist_ok=True)
            shutil.copy(src, dst)

# %% [markdown]
# ## run

# %%
# data
train_dir = '/content/train_set'
test_dir = '/content/test_set'
# Define constants
batch_size = 32
image_size = (224, 224)
epochs = 30

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    validation_split=0.2  # Split 20% of the data for validation
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use the training split
)
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use the validation split
)
# Out:
# Found 2560 images belonging to 8 classes.
# Found 640 images belonging to 8 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1.0 / 255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size = batch_size,
    class_mode = 'categorical',
    shuffle = False
)
# Out:
# Found 800 images belonging to 8 classes.

# %% [markdown]
# # mobilenetv2

# %%
# library

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Load pre-trained VGG16 model
model_MobileNetV2 = MobileNetV2(weights='imagenet',
                   include_top=False,
                   input_shape=(224, 224, 3))

for layer in model_MobileNetV2.layers:
    layer.trainable = False


# Build custom classification head
m1 = Sequential()
m1.add(model_MobileNetV2)
m1.add(Flatten())
m1.add(Dense(256, activation='relu'))
m1.add(Dropout(0.5))
m1.add(Dense(8, activation='softmax'))

# Compile the model
optimizer = Adam(learning_rate=0.050)


m1.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Train the model
history_m1 = m1.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.2836 - loss: 6.1598 - val_accuracy: 0.2562 - val_loss: 7.0410
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.2301 - loss: 4.9470 - val_accuracy: 0.2641 - val_loss: 1.7939
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.2454 - loss: 1.7844 - val_accuracy: 0.2641 - val_loss: 1.7954
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.2479 - loss: 1.7516 - val_accuracy: 0.2625 - val_loss: 1.8005
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.2486 - loss: 1.7983 - val_accuracy: 0.2641 - val_loss: 1.8071
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.2458 - loss: 1.7746 - val_accuracy: 0.2641 - val_loss: 1.8062
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.2410 - loss: 1.7673 - val_accuracy: 0.2625 - val_loss: 1.8083
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.2635 - loss: 1.7447 - val_accuracy: 0.2641 - val_loss: 1.7945
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.2416 - loss: 1.7750 - val_accuracy: 0.2625 - val_loss: 1.8029
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.2431 - loss: 1.7752 - val_accuracy: 0.2625 - val_loss: 1.8102
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.2423 - loss: 1.7737 - val_accuracy: 0.2641 - val_loss: 1.7992
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.2479 - loss: 1.7984 - val_accuracy: 0.2641 - val_loss: 1.7983
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.2246 - loss: 1.8011 - val_accuracy: 0.2641 - val_loss: 1.8052

# %%
 # Visualize training and validation loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_m1.history['loss'], label='Train Loss')
plt.plot(history_m1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_m1.history['accuracy'], label='Train Accuracy')
plt.plot(history_m1.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
# Generate predictions for the test set
predictions_m1 = m1.predict(test_generator)

# Use the true labels directly
y_true_m1 = test_generator.labels

# Convert predicted probabilities to class labels
y_pred_m1 = np.argmax(predictions_m1, axis=1)

# Classification Report
class_report_m1 = classification_report(y_true_m1, y_pred_m1)
print("Classification Report:")
print(class_report_m1)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       100
#            1       1.00      0.01      0.02       100
#            2       0.99      1.00      1.00       100
#            3       1.00      0.11      0.20       100
#            4       1.00      0.05      0.10       100
#            5       0.15      1.00      0.26       100
#            6       0.00      0.00      0.00       100
#            7       1.00      0.01      0.02       100
#
#     accuracy                           0.27       800
#    macro avg       0.64      0.27      0.20       800
# weighted avg       0.64      0.27      0.20       800

# %%
from sklearn.metrics import accuracy_score

# Calculate the accuracy
accuracy_m1 = accuracy_score(y_true_m1, y_pred_m1)

# Print the accuracy
print("Accuracy:", accuracy_m1)
# Out:
# Accuracy: 0.2725

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
confusion_m1= confusion_matrix(y_true_m1, y_pred_m1)

# Define class labels (you can get them from the generator)
class_labels = list(test_generator.class_indices.keys())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(confusion_m1, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Generate predictions for the test set
predictions_m1 = m1.predict(test_generator)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(class_labels)):
    fpr[i], tpr[i], _ = roc_curve(y_true_m1, predictions_m1[:, i], pos_label=i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plotting the ROC curve
plt.figure(figsize=(8, 6))
for i in range(len(class_labels)):
    plt.plot(fpr[i], tpr[i], lw=2, label='ROC curve for class {0} (area = {1:0.2f})'.format(class_labels[i], roc_auc[i]))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step

# %%
m1.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # learning rate = 0.075

# %%
# library

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt

# Load pre-trained VGG16 model
model_MobileNetV2 = MobileNetV2(weights='imagenet',
                   include_top=False,
                   input_shape=(224, 224, 3))

for layer in model_MobileNetV2.layers:
    layer.trainable = False


# Build custom classification head
m1 = Sequential()
m1.add(model_MobileNetV2)
m1.add(Flatten())
m1.add(Dense(256, activation='relu'))
m1.add(Dropout(0.5))
m1.add(Dense(8, activation='softmax'))

# Compile the model
optimizer = Adam(learning_rate=0.075)


m1.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Train the model
history_m1 = m1.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - accuracy: 0.4076 - loss: 1226.9830 - val_accuracy: 0.4531 - val_loss: 2.2542
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.3718 - loss: 11.8657 - val_accuracy: 0.3766 - val_loss: 3.4559
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.3520 - loss: 22.6382 - val_accuracy: 0.4203 - val_loss: 1.6214
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.3424 - loss: 11.4433 - val_accuracy: 0.3781 - val_loss: 4.3342
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3149 - loss: 12.5367 - val_accuracy: 0.3391 - val_loss: 1.8869
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.3117 - loss: 2.2330 - val_accuracy: 0.2906 - val_loss: 1.6263
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.2921 - loss: 2.5940 - val_accuracy: 0.2875 - val_loss: 1.6326
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.2802 - loss: 1.6604 - val_accuracy: 0.2875 - val_loss: 1.6325
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.2953 - loss: 3.2524 - val_accuracy: 0.2906 - val_loss: 1.6294
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.2998 - loss: 1.6158 - val_accuracy: 0.2922 - val_loss: 1.6244
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.2712 - loss: 1.6377 - val_accuracy: 0.2906 - val_loss: 1.6233
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.2416 - loss: 1.7965 - val_accuracy: 0.2875 - val_loss: 1.6845
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.2407 - loss: 1.8027 - val_accuracy: 0.2875 - val_loss: 1.6673
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.2521 - loss: 1.7989 - val_accuracy: 0.2859 - val_loss: 1.6635

# %%
 # Visualize training and validation loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_m1.history['loss'], label='Train Loss')
plt.plot(history_m1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_m1.history['accuracy'], label='Train Accuracy')
plt.plot(history_m1.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
# Generate predictions for the test set
predictions_m1 = m1.predict(test_generator)

# Use the true labels directly
y_true_m1 = test_generator.labels

# Convert predicted probabilities to class labels
y_pred_m1 = np.argmax(predictions_m1, axis=1)

# Classification Report
class_report_m1 = classification_report(y_true_m1, y_pred_m1)
print("Classification Report:")
print(class_report_m1)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.04       100
#            1       1.00      0.04      0.08       100
#            2       1.00      0.99      0.99       100
#            3       1.00      0.01      0.02       100
#            4       1.00      0.02      0.04       100
#            5       0.15      1.00      0.26       100
#            6       0.00      0.00      0.00       100
#            7       1.00      0.29      0.45       100
#
#     accuracy                           0.30       800
#    macro avg       0.77      0.30      0.24       800
# weighted avg       0.77      0.30      0.24       800

# %%
from sklearn.metrics import accuracy_score

# Calculate the accuracy
accuracy_m1 = accuracy_score(y_true_m1, y_pred_m1)

# Print the accuracy
print("Accuracy:", accuracy_m1)
# Out:
# Accuracy: 0.29625

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
confusion_m1= confusion_matrix(y_true_m1, y_pred_m1)

# Define class labels (you can get them from the generator)
class_labels = list(test_generator.class_indices.keys())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(confusion_m1, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #  learning rate = 0.025

# %%
# library

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt

# Load pre-trained VGG16 model
model_MobileNetV2 = MobileNetV2(weights='imagenet',
                   include_top=False,
                   input_shape=(224, 224, 3))

for layer in model_MobileNetV2.layers:
    layer.trainable = False


# Build custom classification head
m1 = Sequential()
m1.add(model_MobileNetV2)
m1.add(Flatten())
m1.add(Dense(256, activation='relu'))
m1.add(Dropout(0.5))
m1.add(Dense(8, activation='softmax'))

# Compile the model
optimizer = Adam(learning_rate=0.025)


m1.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Train the model
history_m1 = m1.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.5332 - loss: 210.3545 - val_accuracy: 0.7516 - val_loss: 2.4995
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step - accuracy: 0.5799 - loss: 5.8625 - val_accuracy: 0.6984 - val_loss: 1.1807
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.5846 - loss: 1.9048 - val_accuracy: 0.7500 - val_loss: 1.3248
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.5552 - loss: 2.0636 - val_accuracy: 0.7312 - val_loss: 1.2412
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.5316 - loss: 2.5676 - val_accuracy: 0.6656 - val_loss: 1.0899
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.5678 - loss: 2.3313 - val_accuracy: 0.6562 - val_loss: 1.3902
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.5108 - loss: 1.7089 - val_accuracy: 0.7531 - val_loss: 1.7223
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.5861 - loss: 1.1001 - val_accuracy: 0.6484 - val_loss: 0.8539
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.5019 - loss: 1.4252 - val_accuracy: 0.6187 - val_loss: 0.9024
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.4748 - loss: 1.5719 - val_accuracy: 0.6031 - val_loss: 1.0243
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.4661 - loss: 1.3249 - val_accuracy: 0.5969 - val_loss: 0.9888
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.4868 - loss: 1.6467 - val_accuracy: 0.6734 - val_loss: 1.0739
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.4858 - loss: 1.5225 - val_accuracy: 0.6484 - val_loss: 1.0869
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.4747 - loss: 1.5805 - val_accuracy: 0.6469 - val_loss: 1.1522
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.4715 - loss: 1.5145 - val_accuracy: 0.6047 - val_loss: 1.0764
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.4291 - loss: 2.8353 - val_accuracy: 0.6172 - val_loss: 1.0417
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.4485 - loss: 1.5622 - val_accuracy: 0.6656 - val_loss: 0.9385
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.4568 - loss: 2.4631 - val_accuracy: 0.6000 - val_loss: 1.1028
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.4329 - loss: 1.3533 - val_accuracy: 0.6906 - val_loss: 1.0924
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.4412 - loss: 1.3321 - val_accuracy: 0.6578 - val_loss: 1.1792
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.4561 - loss: 1.3189 - val_accuracy: 0.6641 - val_loss: 1.1627
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.4479 - loss: 1.9736 - val_accuracy: 0.4656 - val_loss: 1.2488
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.3709 - loss: 1.9106 - val_accuracy: 0.4688 - val_loss: 1.2531
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.3559 - loss: 1.5846 - val_accuracy: 0.4203 - val_loss: 1.3682
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.3501 - loss: 1.5463 - val_accuracy: 0.4219 - val_loss: 1.3690
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.3520 - loss: 1.5547 - val_accuracy: 0.4031 - val_loss: 1.3176
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.3593 - loss: 1.8439 - val_accuracy: 0.4547 - val_loss: 1.9331
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.3427 - loss: 2.6280 - val_accuracy: 0.4563 - val_loss: 1.2889
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.3632 - loss: 1.5586 - val_accuracy: 0.5000 - val_loss: 1.2264
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.3485 - loss: 1.6094 - val_accuracy: 0.4563 - val_loss: 1.2989
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.3389 - loss: 1.6607 - val_accuracy: 0.3922 - val_loss: 1.4365
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.3304 - loss: 1.5776 - val_accuracy: 0.4812 - val_loss: 1.2481
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3386 - loss: 1.7220 - val_accuracy: 0.4281 - val_loss: 1.3478
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.3375 - loss: 1.5852 - val_accuracy: 0.4281 - val_loss: 1.3468
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.3240 - loss: 1.6065 - val_accuracy: 0.4297 - val_loss: 1.3498
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3199 - loss: 1.5858 - val_accuracy: 0.4281 - val_loss: 1.3469
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.3323 - loss: 1.5599 - val_accuracy: 0.4281 - val_loss: 1.3394
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.3389 - loss: 2.2519 - val_accuracy: 0.4203 - val_loss: 1.3780
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.3114 - loss: 1.5933 - val_accuracy: 0.4203 - val_loss: 1.3784
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.3323 - loss: 1.5765 - val_accuracy: 0.4203 - val_loss: 1.3763
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.3228 - loss: 1.5623 - val_accuracy: 0.4219 - val_loss: 1.3843
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.3143 - loss: 1.5893 - val_accuracy: 0.4203 - val_loss: 1.3767
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.3062 - loss: 1.5916 - val_accuracy: 0.4203 - val_loss: 1.3803
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.3075 - loss: 1.5942 - val_accuracy: 0.4219 - val_loss: 1.3833
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.3310 - loss: 1.5765 - val_accuracy: 0.4187 - val_loss: 1.3812
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.3171 - loss: 1.7098 - val_accuracy: 0.4219 - val_loss: 1.3814
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.3351 - loss: 1.5839 - val_accuracy: 0.4203 - val_loss: 1.3773
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.3174 - loss: 1.6006 - val_accuracy: 0.4203 - val_loss: 1.3763
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.3261 - loss: 1.5688 - val_accuracy: 0.3750 - val_loss: 1.3801
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.3094 - loss: 1.5812 - val_accuracy: 0.4203 - val_loss: 1.3811

# %%
 # Visualize training and validation loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_m1.history['loss'], label='Train Loss')
plt.plot(history_m1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_m1.history['accuracy'], label='Train Accuracy')
plt.plot(history_m1.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
# Generate predictions for the test set
predictions_m1 = m1.predict(test_generator)

# Use the true labels directly
y_true_m1 = test_generator.labels

# Convert predicted probabilities to class labels
y_pred_m1 = np.argmax(predictions_m1, axis=1)

# Classification Report
class_report_m1 = classification_report(y_true_m1, y_pred_m1)
print("Classification Report:")
print(class_report_m1)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       100
#            1       0.00      0.00      0.00       100
#            2       0.99      0.99      0.99       100
#            3       1.00      0.24      0.39       100
#            4       1.00      0.10      0.18       100
#            5       0.17      1.00      0.29       100
#            6       1.00      0.13      0.23       100
#            7       1.00      0.52      0.68       100
#
#     accuracy                           0.37       800
#    macro avg       0.64      0.37      0.34       800
# weighted avg       0.64      0.37      0.34       800

# %%
from sklearn.metrics import accuracy_score

# Calculate the accuracy
accuracy_m1 = accuracy_score(y_true_m1, y_pred_m1)

# Print the accuracy
print("Accuracy:", accuracy_m1)
# Out:
# Accuracy: 0.3725

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
confusion_m1= confusion_matrix(y_true_m1, y_pred_m1)

# Define class labels (you can get them from the generator)
class_labels = list(test_generator.class_indices.keys())

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(confusion_m1, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Adam = 0.0100

# %%
# library

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# Load pre-trained VGG16 model
model_MobileNetV2 = MobileNetV2(weights='imagenet',
                   include_top=False,
                   input_shape=(224, 224, 3))

for layer in model_MobileNetV2.layers:
    layer.trainable = False


# Build custom classification head
m1 = Sequential()
m1.add(model_MobileNetV2)
m1.add(Flatten())
m1.add(Dense(256, activation='relu'))
m1.add(Dropout(0.5))
m1.add(Dense(8, activation='softmax'))

# Compile the model
optimizer = Adam(learning_rate=0.0100)


m1.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Train the model
history_m1 = m1.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator
)
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 15s 108ms/step - accuracy: 0.6154 - loss: 78.1611 - val_accuracy: 0.8625 - val_loss: 1.1771
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.8094 - loss: 1.5133 - val_accuracy: 0.8422 - val_loss: 1.2811
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.8027 - loss: 1.0894 - val_accuracy: 0.8313 - val_loss: 2.7810
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.7841 - loss: 1.3339 - val_accuracy: 0.7891 - val_loss: 1.4205
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7654 - loss: 1.1482 - val_accuracy: 0.8188 - val_loss: 1.5404
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.7203 - loss: 1.7505 - val_accuracy: 0.8453 - val_loss: 0.8795
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.7529 - loss: 1.3997 - val_accuracy: 0.7969 - val_loss: 0.9924
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.7482 - loss: 1.2486 - val_accuracy: 0.8141 - val_loss: 0.9997
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.6965 - loss: 0.9757 - val_accuracy: 0.8797 - val_loss: 1.8416
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.7534 - loss: 1.3376 - val_accuracy: 0.7891 - val_loss: 1.6939
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.7251 - loss: 0.9858 - val_accuracy: 0.8500 - val_loss: 1.3089
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7714 - loss: 1.0771 - val_accuracy: 0.8422 - val_loss: 0.8393
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.7688 - loss: 0.7468 - val_accuracy: 0.7984 - val_loss: 0.8849
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.7460 - loss: 0.9448 - val_accuracy: 0.7688 - val_loss: 0.7979
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.7249 - loss: 0.8384 - val_accuracy: 0.7984 - val_loss: 2.0228
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.7531 - loss: 0.9783 - val_accuracy: 0.7047 - val_loss: 1.1204
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.7162 - loss: 0.8826 - val_accuracy: 0.8281 - val_loss: 1.1351
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.6762 - loss: 1.1434 - val_accuracy: 0.7719 - val_loss: 1.8657
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.6347 - loss: 1.3420 - val_accuracy: 0.7594 - val_loss: 3.0459
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.6316 - loss: 1.9159 - val_accuracy: 0.6531 - val_loss: 0.9317
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.6558 - loss: 0.8947 - val_accuracy: 0.8578 - val_loss: 0.9198
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.6603 - loss: 1.4553 - val_accuracy: 0.8109 - val_loss: 1.2972
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.6747 - loss: 1.5148 - val_accuracy: 0.7828 - val_loss: 2.6238
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.6321 - loss: 1.8402 - val_accuracy: 0.7375 - val_loss: 1.0315
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.6262 - loss: 1.1732 - val_accuracy: 0.8078 - val_loss: 0.7586
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.6268 - loss: 1.0184 - val_accuracy: 0.7391 - val_loss: 0.8927
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.6023 - loss: 1.4198 - val_accuracy: 0.7000 - val_loss: 0.8772
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.5515 - loss: 1.4051 - val_accuracy: 0.6922 - val_loss: 3.2726
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.5487 - loss: 1.9091 - val_accuracy: 0.6703 - val_loss: 1.1286
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.5650 - loss: 1.0970 - val_accuracy: 0.7734 - val_loss: 0.9759
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.6013 - loss: 1.1709 - val_accuracy: 0.7406 - val_loss: 3.6672
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.6037 - loss: 1.0806 - val_accuracy: 0.7500 - val_loss: 1.1877
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.6088 - loss: 1.0808 - val_accuracy: 0.7203 - val_loss: 1.3873
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5644 - loss: 1.0853 - val_accuracy: 0.7437 - val_loss: 1.2222
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5418 - loss: 1.1678 - val_accuracy: 0.7109 - val_loss: 1.5692
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.5671 - loss: 1.1043 - val_accuracy: 0.6578 - val_loss: 1.4310
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.5316 - loss: 1.1037 - val_accuracy: 0.6969 - val_loss: 1.3476
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.5505 - loss: 1.1080 - val_accuracy: 0.7031 - val_loss: 1.3408
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.5506 - loss: 1.0959 - val_accuracy: 0.7422 - val_loss: 1.6539
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.5394 - loss: 1.1281 - val_accuracy: 0.7578 - val_loss: 1.2399
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.5756 - loss: 1.0940 - val_accuracy: 0.7641 - val_loss: 1.2456
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.5582 - loss: 1.6035 - val_accuracy: 0.6891 - val_loss: 1.3682
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.5238 - loss: 1.1345 - val_accuracy: 0.6625 - val_loss: 1.4064
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.5024 - loss: 1.1488 - val_accuracy: 0.6984 - val_loss: 1.3377
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.5457 - loss: 1.0986 - val_accuracy: 0.6609 - val_loss: 1.3261
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.5239 - loss: 1.1226 - val_accuracy: 0.6797 - val_loss: 1.6471
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.5307 - loss: 1.2686 - val_accuracy: 0.6484 - val_loss: 1.3418
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - accuracy: 0.5088 - loss: 1.1497 - val_accuracy: 0.6594 - val_loss: 1.4767
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.5267 - loss: 1.1116 - val_accuracy: 0.6656 - val_loss: 1.4598
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.5287 - loss: 1.1211 - val_accuracy: 0.7109 - val_loss: 1.5259

# %%
 # Visualize training and validation loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_m1.history['loss'], label='Train Loss')
plt.plot(history_m1.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_m1.history['accuracy'], label='Train Accuracy')
plt.plot(history_m1.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
# Generate predictions for the test set
predictions_m1 = m1.predict(test_generator)

# Use the true labels directly
y_true_m1 = test_generator.labels

# Convert predicted probabilities to class labels
y_pred_m1 = np.argmax(predictions_m1, axis=1)

# Classification Report
class_report_m1 = classification_report(y_true_m1, y_pred_m1)
print("Classification Report:")
print(class_report_m1)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20       100
#            1       1.00      0.86      0.92       100
#            2       1.00      1.00      1.00       100
#            3       0.98      1.00      0.99       100
#            4       0.29      1.00      0.45       100
#            5       0.96      0.89      0.92       100
#            6       0.92      0.11      0.20       100
#            7       1.00      0.48      0.65       100
#
#     accuracy                           0.68       800
#    macro avg       0.89      0.68      0.67       800
# weighted avg       0.89      0.68      0.67       800

# %%
from sklearn.metrics import accuracy_score

# Calculate the accuracy
accuracy_m1 = accuracy_score(y_true_m1, y_pred_m1)

# Print the accuracy
print("Accuracy:", accuracy_m1)
# Out:
# Accuracy: 0.68125

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
# Generate predictions for the test set
predictions_m1 = m1.predict(test_generator)

# Use the true labels directly
y_true_m1 = test_generator.labels

# Convert predicted probabilities to class labels
y_pred_m1 = np.argmax(predictions_m1, axis=1)

# Classification Report
class_report_m1 = classification_report(y_true_m1, y_pred_m1)
print("Classification Report:")
print(class_report_m1)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20       100
#            1       1.00      0.86      0.92       100
#            2       1.00      1.00      1.00       100
#            3       0.98      1.00      0.99       100
#            4       0.29      1.00      0.45       100
#            5       0.96      0.89      0.92       100
#            6       0.92      0.11      0.20       100
#            7       1.00      0.48      0.65       100
#
#     accuracy                           0.68       800
#    macro avg       0.89      0.68      0.67       800
# weighted avg       0.89      0.68      0.67       800
